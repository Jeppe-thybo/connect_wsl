# %%
from classy_SIDR_DRMD import Class

# %%
cosmo = Class()
cosmo.set({'output': 'tCl, mPk',
           'omega_b': 0.022,
           'omega_cdm': 0.12,
           'h': 0.67,
           'ln10^{10}A_s': 3.0,
           'n_s': 0.96,
           'tau_reio': 0.06,
           'r': 0.1,
           'm_ncdm_interacting': 0.1,
           'deg_ncdm_interacting': 3,
           'log10G_eff_ncdm_interacting': -2.0,
           'f_idm_drmd': 0.02,
           'delta_Neff_drmd': 1.0,
           'z_stop': 10000,
           'G_over_aH_drmd_ini': 100000000,
           'k_pivot': 0.05,	   
           'N_ncdm_interacting' : 1.0,
           'ncdm_fluid_approximation': 3.0,
           'modes': 's,t',
           'N_ur': 0,
           'P_k_max_h/Mpc': 1.0,
           'start_large_k_at_tau_h_over_tau_k': 0.00002
              })
cosmo.compute()

# %%
# omega_b	omega_cdm	h	ln10^{10}A_s	n_s	tau_reio	r	m_ncdm_interacting	log10G_eff_ncdm_interacting	deg_ncdm_interacting	delta_Neff_drmd	f_idm_drmd	log10z_stop	log10_G_over_aH_drmd
#0.021748662599504302	0.11751322235061937	0.7152973437522895	3.122856848707421	0.9577453061938386	0.05897479703525638	0.2010854705585774	0.4869854251685152	-4.#243651409184998	3.9066552858475347	1.5376827155522441	0.9000203527835501	2.571986060482885	9.213989338151444
cosmo = Class()
cosmo.set({'output': 'tCl, mPk',
              'omega_b': 0.021748662599504302,
              'omega_cdm': 0.11751322235061937,
              'h': 0.7152973437522895,
              'ln10^{10}A_s': 3.122856848707421,
              'n_s': 0.9577453061938386,
              'tau_reio': 0.05897479703525638,
              'r': 0.2010854705585774,
              'm_ncdm_interacting': 0.4869854251685152,
              'deg_ncdm_interacting': 3.9066552858475347,
              'log10G_eff_ncdm_interacting': -4.243651409184998,
              'f_idm_drmd': 0.9000203527835501,
              'delta_Neff_drmd': 1.5376827155522441,
              'z_stop': 10000,
              'G_over_aH_drmd_ini': 10000000000,
              'k_pivot': 0.05,	   
              'N_ncdm_interacting' : 1.0,
              'ncdm_fluid_approximation': 3.0,
              'modes': 's,t',
              'N_ur': 0,
              'P_k_max_h/Mpc': 1.0,
              'start_large_k_at_tau_h_over_tau_k': 0.00002
                  })

cosmo.compute()

# %%
# omega_b	omega_cdm	h	ln10^{10}A_s	n_s	tau_reio	r	m_ncdm_interacting	log10G_eff_ncdm_interacting	deg_ncdm_interacting	delta_Neff_drmd	f_idm_drmd	log10z_stop	log10_G_over_aH_drmd
#0.021748662599504302	0.11751322235061937	0.7152973437522895	3.122856848707421	0.9577453061938386	0.05897479703525638	0.2010854705585774	0.4869854251685152	-4.#243651409184998	3.9066552858475347	1.5376827155522441	0.9000203527835501	2.571986060482885	9.213989338151444
cosmo = Class()
cosmo.set({'output': 'tCl, mPk',
              'omega_b': 0.021748662599504302,
              'omega_cdm': 0.11751322235061937,
              'h': 0.7152973437522895,
              'ln10^{10}A_s': 3.122856848707421,
              'n_s': 0.9577453061938386,
              'tau_reio': 0.05897479703525638,
              'r': 0.2010854705585774,
              'm_ncdm_interacting': 0.4869854251685152,
              'deg_ncdm_interacting': 3.9066552858475347,
              'log10G_eff_ncdm_interacting': -4.243651409184998,
              'f_idm_drmd': 0.9000203527835501,
              'delta_Neff_drmd': 1.5376827155522441,
              'log10z_stop': 4.5,
              'log10_G_over_aH_drmd': 12,
              'k_pivot': 0.05,	   
              'N_ncdm_interacting' : 1.0,
              'ncdm_fluid_approximation': 3.0,
              'modes': 's,t',
              'N_ur': 0,
              'P_k_max_h/Mpc': 1.0,
              'start_large_k_at_tau_h_over_tau_k': 0.00002
                  })

cosmo.compute()

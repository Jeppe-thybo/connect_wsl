# %%
# omega_b	omega_cdm	100*theta_s	ln10^{10}A_s	n_s	tau_reio	r	m_ncdm_interacting	log10G_eff_ncdm_interacting	deg_ncdm_interacting	m_ncdm_standard	deg_ncdm_standard
#0.021770588035785035	0.11706517883902084	1.0410312532724082	3.092274451515235	0.9621509496150122	0.06544502070680035	0.03672560332737658	0.5623136628117981	-2.192531792905502	2.837699750212251	0.681568543148232	0.5087853576930514

from classy_nu import Class

# %%
cosmo = Class()
cosmo.set({
    'omega_b': 0.021770588035785035,
    'omega_cdm': 0.11706517883902084,
    '100*theta_s': 1.0410312532724082,
    'ln10^{10}A_s': 3.092274451515235,
    'n_s': 0.9621509496150122,
    'tau_reio': 0.06544502070680035,
    'r': 0.03672560332737658,
    'm_ncdm_interacting': 0.5623136628117981,
    'log10G_eff_ncdm_interacting': -2.192531792905,
    'deg_ncdm_interacting': 2.837699750212251,
    'm_ncdm_standard': 0.681568543148232,
    'deg_ncdm_standard': 0.5087853576930514,

    'N_ncdm_interacting': 1,
    'N_ncdm_standard': 1,
    'lensing': 'yes',
    'output': 'tCl,pCl,lCl,mPk',
    'P_k_max_h/Mpc': 1.0,
    'k_pivot': 0.05,
    'ncdm_fluid_approximation': 3,
    'N_ur': 0,
    'modes': 's,t',

})
cosmo.compute()

# %%
#0.02152078893202768	0.12343332890825941	1.0406398600724074	3.1375444399557155	0.9671440627411024	0.073849466344791	0.24584738138232964	0.6029785482490145	-2.007738771887966	1.4260229655020173	0.12646714043170793	2.338376029416248


cosmo = Class()
cosmo.set({
    'omega_b': 0.02152078893202768,
    'omega_cdm': 0.12343332890825941,
    '100*theta_s': 1.0406398600724074,
    'ln10^{10}A_s': 3.1375444399557155,
    'n_s': 0.9671440627411024,
    'tau_reio': 0.073849466344791,
    'r': 0.24584738138232964,
    'm_ncdm_interacting': 0.6029785482490145,
    'log10G_eff_ncdm_interacting': -2.007738771887,
    'deg_ncdm_interacting': 1.4260229655020173,
    'm_ncdm_standard': 0.12646714043170793,
    'deg_ncdm_standard': 2.338376029416248,
    'N_ncdm_interacting': 1,
    'N_ncdm_standard': 1,
    'lensing': 'yes',
    'output': 'tCl,pCl,lCl,mPk',
    'P_k_max_h/Mpc': 1.0,
    'k_pivot': 0.05,
    'ncdm_fluid_approximation': 3,
    'N_ur': 0,
    'modes': 's,t',
})
cosmo.compute()

# %%
#0.022112452961347184	0.12495402575907032	1.0394133374902654	3.0888513094521453	0.9463587689597923	0.03194879488699264	0.16799417056501323	0.17355790995252707	-1.959276621032572	0.6250608759983336	0.2884967629659218	0.9449140218548342

cosmo = Class()
cosmo.set({
    'omega_b': 0.022112452961347184,
    'omega_cdm': 0.12495402575907032,
    '100*theta_s': 1.0394133374902654,
    'ln10^{10}A_s': 3.0888513094521453,
    'n_s': 0.9463587689597923,
    'tau_reio': 0.03194879488699264,
    'r': 0.16799417056501323,
    'm_ncdm_interacting': 0.17355790995252707,
    'log10G_eff_ncdm_interacting': -1.959276621032,
    'deg_ncdm_interacting': 0.6250608759983336,
    'm_ncdm_standard': 0.2884967629659218,
    'deg_ncdm_standard': 0.9449140218548342,
    'N_ncdm_interacting': 1,
    'N_ncdm_standard': 1,
    'lensing': 'yes',
    'output': 'tCl,pCl,lCl,mPk',
    'P_k_max_h/Mpc': 1.0,
    'k_pivot': 0.05,
    'ncdm_fluid_approximation': 3,
    'N_ur': 0,
    'modes': 's,t',
})
cosmo.compute()

# %%
params_directory = "/home/jthybo/connect_wsl/data/SIDR_interacting_and_std/N-2000/model_params_data/"

import os

for filename in os.listdir(params_directory):
    if filename.endswith(".txt"):
        with open(os.path.join(params_directory, filename), 'r') as f:
            lines = [line.strip() for line in f]
            if lines[-1] == lines[-2]:
                print('True')
            else:
                print('False')
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %%
#0.022258123465211256	0.1192787002532669	1.0392311113433634	3.058800677419271	0.9584383689941077	0.045642027581247566	0.2186562573701976	0.1438680810866919	-4.106489053539348	4.071723038052237	0.06155914122628142	4.340036967910069

cosmo = Class()
cosmo.set({
    'omega_b': 0.022258123465211256,
    'omega_cdm': 0.1192787002532669,
    '100*theta_s': 1.0392311113433634,
    'ln10^{10}A_s': 3.058800677419271,
    'n_s': 0.9584383689941077,
    'tau_reio': 0.045642027581247566,
    'r': 0.2186562573701976,
    'm_ncdm_interacting': 0.1438680810866919,
    'log10G_eff_ncdm_interacting': -4.106489053539,
    'deg_ncdm_interacting': 4.071723038052237,
    'm_ncdm_standard': 0.06155914122628142,
    'deg_ncdm_standard': 4.340036967910069,
    'N_ncdm_interacting': 1,
    'N_ncdm_standard': 1,
    'lensing': 'yes',
    'output': 'tCl,pCl,lCl,mPk',
    'P_k_max_h/Mpc': 1.0,
    'k_pivot': 0.05,
    'ncdm_fluid_approximation': 3,
    'N_ur': 0,
    'modes': 's,t',
})
cosmo.compute()
